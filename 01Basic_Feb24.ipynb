# %%
pass = 7
# keywords cannot be used as identifiers
# Out:
#   Cell In[7], line 1
#     pass = 7
#          ^
# SyntaxError: invalid syntax

# %%
Pass = 7

# %%
Pass
# Out:
# 7

# %%
a = 56
b = 44.55
c = "mitadt"

# %%
a
# Out:
# 56

# %%
b
# Out:
# 44.55

# %%
c
# Out:
# 'mitadt'

# %%
type(a)
# Out:
# int

# %%
print(type(a))
# Out:
# <class 'int'>

# %%
type(b)
# Out:
# float

# %%
type(c)
# Out:
# str

# %%
z = True
type(z)
# Out:
# bool

# %%
# int

# %%
a = 67

# %%
1233654 ** 123
# Out:
# ...

# %%
# string

# %%
name = "MITAdt"

# %%
type(name)
# Out:
# str

# %%
name.lower()
# Out:
# 'mitadt'

# %%
name.upper()
# Out:
# 'MITADT'

# %%
name.title()
# Out:
# 'Mitadt'

# %%
name.startswith("M")
# Out:
# True

# %%
name.startswith("MIt")
# Out:
# False

# %%
name = " MIT "

# %%
name.lstrip()
# Out:
# 'MIT '

# %%
name.rstrip()
# Out:
# ' MIT'

# %%
name.strip()
# Out:
# 'MIT'

# %%
a = "123"
b = "pune"
c = "pune123"

# %%
a.isalpha()
# Out:
# False

# %%
b.isalpha()
# Out:
# True

# %%
c.isalpha()
# Out:
# False

# %%
a.isdigit()
# Out:
# True

# %%
# print

# %%
name = "Ganesh"
marks = 89

# %%
# my name is Ganesh and marks are 89

# %%
print("my name is", name, "and marks are", marks)
# Out:
# my name is Ganesh and marks are 89

# %%
a = 'ok'
b = 'xyz'

# %%
a + ' ' + b #string concat
# Out:
# 'ok xyz'

# %%
print("my name is %s and marks are %i" %(name , marks))
# Out:
# my name is Ganesh and marks are 89

# %%
print("my name is %s and marks are %.2f" %(name , marks))
# Out:
# my name is Ganesh and marks are 89.00

# %%
print(f"my name is {name} and marks are {marks}")
# Out:
# my name is Ganesh and marks are 89

# %%
# operators

# %%
a = 21
b = 5

# %%
a + b
# Out:
# 26

# %%
a - b
# Out:
# 16

# %%
a / b
# Out:
# 4.2

# %%
a * b
# Out:
# 105

# %%
a ** b # raise to
# Out:
# 4084101

# %%
a // b # floor div
# Out:
# 4

# %%
a % b # modulus/ remainder
# Out:
# 1

# %%
a
# Out:
# 21

# %%
b
# Out:
# 5

# %%
a < b
# Out:
# False

# %%
a > b
# Out:
# True

# %%
a <= b
# Out:
# False

# %%
a == b
# Out:
# False

# %%
a != b
# Out:
# True

# %%
a > b and a > 0
# Out:
# True

# %%
a < b and a > 0
# Out:
# False

# %%
a > b or a > 0
# Out:
# True

# %%
a < b or a > 0
# Out:
# True

# %%
b = 10

# %%
b += 2  # b = b + 2

# %%
b
# Out:
# 12

# %%
a = "123"

# %%
type(a)
# Out:
# str

# %%
a + 78
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[182], line 1
# ----> 1 a + 78
#
# TypeError: can only concatenate str (not "int") to str

# %%
a
# Out:
# '123'

# %%
int(a)
# Out:
# 123

# %%
int(a) + 70
# Out:
# 193

# %%
b = "gd"

# %%
int(b)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[192], line 1
# ----> 1 int(b)
#
# ValueError: invalid literal for int() with base 10: 'gd'

# %%
# addition of 2 number

# %%
# user input
a = int(input("enter the 1st number"))
b = int(input("enter the 2nd number"))

res = a + b

print("addition is:", res)
# Out:
# enter the 1st number 10
# enter the 2nd number 20
# addition is: 30

# %%
# fdhbcn
