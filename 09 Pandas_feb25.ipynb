# %%
import pandas as pd
import numpy as np

# %%
s = pd.Series([67, 89, 32, 32, 90])

# %%
s
# Out:
# 0    67
# 1    89
# 2    32
# 3    32
# 4    90
# dtype: int64

# %%
s[4]
# Out:
# 90

# %%
s = pd.Series([67, 89, 32, 32, 90], index= range(100, 105))

# %%
s
# Out:
# 100    67
# 101    89
# 102    32
# 103    32
# 104    90
# dtype: int64

# %%
# dataframe

# %%
roll = pd.Series([1, 2, 3, 4, 5])
name = pd.Series(["rihan", "jay", 'geet', 'vaibhav', 'sia'])
marks = pd.Series([65, 66, 89, 91, 96])

# %%
df = pd.DataFrame({
    "roll": roll,
    "name": name,
    "marks": marks
})

# %%
df
# Out:
#    roll     name  marks
# 0     1    rihan     65
# 1     2      jay     66
# 2     3     geet     89
# 3     4  vaibhav     91
# 4     5      sia     96
