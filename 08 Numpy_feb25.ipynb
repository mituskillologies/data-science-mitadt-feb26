# %%
import numpy as np

# %%
a = np.array([1, 45, 78, 90, True, "ok", 90])

# %%
a
# Out:
# array(['1', '45', '78', '90', 'True', 'ok', '90'], dtype='<U11')

# %%
b = np.array([34, 78, 99.67, 9])
print(b)
# Out:
# [34.   78.   99.67  9.  ]

# %%
b[1] = 800

# %%
b
# Out:
# array([ 34.  , 800.  ,  99.67,   9.  ])

# %%
# duplicates allowed
# homo
# ordered
# mutable

# %%
# speed

# %%
l1 = list(range(1000000))
a1 = np.array(l1)

# %%
import time as t

# %%
t.time()
# Out:
# 1772011887.131438

# %%
# time take by array
start_time = t.time()
newa = a1 * 2
time_arr = t.time() - start_time
print(f"time taken by an array: {time_arr}")
# Out:
# time taken by an array: 0.0015072822570800781

# %%
# time take by list
start_time = t.time()
newl = [i*2 for i in l1]
time_list = t.time() - start_time
print(f"time taken by an list: {time_list}")
# Out:
# time taken by an list: 0.11889076232910156

# %%
time_list/time_arr
# Out:
# 78.87757038911737

# %%
a
# Out:
# array(['1', '45', '78', '90', 'True', 'ok', '90'], dtype='<U11')

# %%
a[1: 4]
# Out:
# array(['45', '78', '90'], dtype='<U11')

# %%
a
# Out:
# array(['1', '45', '78', '90', 'True', 'ok', '90'], dtype='<U11')

# %%
a.ndim
# Out:
# 1

# %%
a.shape
# Out:
# (7,)

# %%
a.size
# Out:
# 7

# %%
# 2d

# %%
arr = np.array([[1, 2, 3], [3, 5, 2], [8, 6, 7], [1, 5, 2]])

# %%
arr
# Out:
# array([[1, 2, 3],
#        [3, 5, 2],
#        [8, 6, 7],
#        [1, 5, 2]])

# %%
arr.ndim
# Out:
# 2

# %%
arr.shape
# Out:
# (4, 3)

# %%
arr.size
# Out:
# 12

# %%
arr[1:3, 0:2]
# Out:
# array([[3, 5],
#        [8, 6]])

# %%
arr
# Out:
# array([[1, 2, 3],
#        [3, 5, 2],
#        [8, 6, 7],
#        [1, 5, 2]])

# %%
arr.reshape(2, 6)
# Out:
# array([[1, 2, 3, 3, 5, 2],
#        [8, 6, 7, 1, 5, 2]])

# %%
arr.reshape(2, 3, 2)
# Out:
# array([[[1, 2],
#         [3, 3],
#         [5, 2]],
#
#        [[8, 6],
#         [7, 1],
#         [5, 2]]])

# %%
arr.flatten()
# Out:
# array([1, 2, 3, 3, 5, 2, 8, 6, 7, 1, 5, 2])

# %%
arr
# Out:
# array([[1, 2, 3],
#        [3, 5, 2],
#        [8, 6, 7],
#        [1, 5, 2]])

# %%
arr.reshape(4, 3, -1)
# Out:
# array([[[1],
#         [2],
#         [3]],
#
#        [[3],
#         [5],
#         [2]],
#
#        [[8],
#         [6],
#         [7]],
#
#        [[1],
#         [5],
#         [2]]])

# %%
arr1 = np.array([[1, 2, 3], [3, 5, 2], [8, 6, 7]])
arr2 = np.array([[1, 2, 1], [9, 5, 2], [6, 9, 7]])

# %%
arr1, arr2
# Out:
# (array([[1, 2, 3],
#         [3, 5, 2],
#         [8, 6, 7]]),
#  array([[1, 2, 1],
#         [9, 5, 2],
#         [6, 9, 7]]))

# %%
np.linalg.det(arr1)
# Out:
# -52.999999999999986

# %%
np.linalg.inv(arr1)
# Out:
# array([[-0.43396226, -0.0754717 ,  0.20754717],
#        [ 0.09433962,  0.32075472, -0.13207547],
#        [ 0.41509434, -0.18867925,  0.01886792]])

# %%
np.linalg.eig(arr1)
# Out:
# EigResult(eigenvalues=array([12.23751293, -1.7344814 ,  2.49696847]), eigenvectors=array([[-0.3003943 , -0.78216395,  0.22141646],
#        [-0.36771625,  0.17044833, -0.75679211],
#        [-0.8800841 ,  0.59930537,  0.61501256]]))

# %%
arr1 @ arr2
# Out:
# array([[ 37,  39,  26],
#        [ 60,  49,  27],
#        [104, 109,  69]])

# %%
np.dot(arr1, arr2)
# Out:
# array([[ 37,  39,  26],
#        [ 60,  49,  27],
#        [104, 109,  69]])

# %%
np.cross(arr1, arr2)
# Out:
# array([[ -4,   2,   0],
#        [  0,  12, -30],
#        [-21, -14,  36]])

# %%
arr1.T
# Out:
# array([[1, 3, 8],
#        [2, 5, 6],
#        [3, 2, 7]])
