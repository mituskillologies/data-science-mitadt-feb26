# %%
add3(8, 9)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 add3(8, 9)
#
# NameError: name 'add3' is not defined

# %%
show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 show()
#
# NameError: name 'show' is not defined

# %%
import mod1

# %%
help(mod1)
# Out:
# Help on module mod1:
#
# NAME
#     mod1
#
# FUNCTIONS
#     show()
#
# FILE
#     c:\users\aditya\mitadt feb 24\mod1.py

# %%
mod1.show()
# Out:
# This is mod1
# module loaded and working
